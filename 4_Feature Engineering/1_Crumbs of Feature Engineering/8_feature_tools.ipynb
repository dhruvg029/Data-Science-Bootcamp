# %% [markdown]
# # Featuretools
#
# ## Importing and loading data
#
# ### Featuretools Installation
#
# Before Running this notebook, you would need to install featuretools in your system with the help of **`!pip install featuretools`** command.

# %%
# Install featuretools
# !pip install featuretools
# Out:
# Collecting featuretools
#   Downloading featuretools-1.31.0-py3-none-any.whl.metadata (15 kB)
# Collecting cloudpickle>=1.5.0 (from featuretools)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting holidays>=0.17 (from featuretools)
#   Downloading holidays-0.52-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from featuretools) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from featuretools) (23.2)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from featuretools) (2.1.1)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\dhruv\appdata\roaming\python\python312\site-packages (from featuretools) (5.9.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from featuretools) (1.13.0)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from featuretools) (4.66.4)
# Collecting woodwork>=0.28.0 (from featuretools)
#   Downloading woodwork-0.31.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from holidays>=0.17->featuretools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->featuretools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->featuretools) (2023.3)
# Requirement already satisfied: colorama in c:\users\dhruv\appdata\roaming\python\python312\site-packages (from tqdm>=4.66.3->featuretools) (0.4.6)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from woodwork>=0.28.0->featuretools) (1.5.0)
# Collecting importlib-resources>=5.10.0 (from woodwork>=0.28.0->featuretools)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil->holidays>=0.17->featuretools) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1.0->woodwork>=0.28.0->featuretools) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dhruv\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1.0->woodwork>=0.28.0->featuretools) (3.5.0)
# Downloading featuretools-1.31.0-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.9 kB ? eta -:--:--
#    --------------------------------------  583.7/587.9 kB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 587.9/587.9 kB 9.2 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading holidays-0.52-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 32.2 MB/s eta 0:00:00
# Downloading woodwork-0.31.0-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.2 kB ? eta -:--:--
#    --------------------------------------- 215.2/215.2 kB 12.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: importlib-resources, cloudpickle, holidays, woodwork, featuretools
# Successfully installed cloudpickle-3.0.0 featuretools-1.31.0 holidays-0.52 importlib-resources-6.4.0 woodwork-0.31.0
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

import featuretools as ft

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline

print(pd.__version__)
print(np.__version__)
# Out:
# 2.1.1
# 1.26.1

# %%
# Loading the data
data = pd.read_csv('datasets/train_bm.csv')

# Check the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Splitting dependent and independent variables
X = data.drop('Item_Outlet_Sales', axis=1)
y = data['Item_Outlet_Sales']

print(X.shape, y.shape)
# Out:
# (8523, 11) (8523,)

# %% [markdown]
# ## Entityset and it's features
#
# ### Creating an entity set

# %%
# Create an entity set
es = ft.EntitySet(id = 'sales_data')
print(es)
# Out:
# Entityset: sales_data
#   DataFrames:
#   Relationships:
#     No relationships

# %% [markdown]
# ### Add data to this entityset created

# %%
es.add_dataframe(dataframe_name = 'data', dataframe = X, make_index = True, index = 'index')

print(es)
# Out:
# Entityset: sales_data
#   DataFrames:
#     data [Rows: 8523, Columns: 12]
#   Relationships:
#     No relationships

# %% [markdown]
# ### Feature Engineering

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_dataframe_name = 'data', max_depth=1, trans_primitives = ['add_numeric', 'multiply_numeric'])

# Check the data
feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP + Outlet_Establishment_Year  Item_Visibility + Item_Weight  \
# index
# 0                                2248.8092                       9.316047
# 1                                2057.2692                       5.939278
# 2                                2140.6180                      17.516760
# 3                                2180.0950                      19.200000
# 4                                2040.8614                       8.930000
#
#        Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                      1999.016047
# 1                                      2009.019278
# 2                                      1999.016760
# 3                                      1998.000000
# 4                                      1987.000000
#
#        Item_Weight + Outlet_Establishment_Year  Item_MRP * Item_Visibility  \
# index
# 0                                      2008.30                    4.008763
# 1                                      2014.92                    0.930544
# 2                                      2016.50                    2.373528
# 3                                      2017.20                    0.000000
# 4                                      1995.93                    0.000000
#
#        Item_MRP * Item_Weight  Item_MRP * Outlet_Establishment_Year  \
# index
# 0                 2323.225560                           499368.5908
# 1                  285.753664                            96972.8228
# 2                 2478.315000                           283094.3820
# 3                 3496.224000                           363825.8100
# 4                  480.982302                           107022.6018
#
#        Item_Visibility * Item_Weight  \
# index
# 0                           0.149240
# 1                           0.114127
# 2                           0.293301
# 3                           0.000000
# 4                           0.000000
#
#        Item_Visibility * Outlet_Establishment_Year  \
# index
# 0                                        32.078555
# 1                                        38.729936
# 2                                        33.503390
# 3                                         0.000000
# 4                                         0.000000
#
#        Item_Weight * Outlet_Establishment_Year
# index
# 0                                     18590.70
# 1                                     11893.28
# 2                                     34982.50
# 3                                     38361.60
# 4                                     17743.91
#
# [5 rows x 23 columns]

# %%
# Check the feature definitions
print('Definitions:', feature_defs)
print('Shape:', feature_matrix.shape)
# Out:
# Definitions: [<Feature: Item_Identifier>, <Feature: Item_Weight>, <Feature: Item_Fat_Content>, <Feature: Item_Visibility>, <Feature: Item_Type>, <Feature: Item_MRP>, <Feature: Outlet_Identifier>, <Feature: Outlet_Establishment_Year>, <Feature: Outlet_Size>, <Feature: Outlet_Location_Type>, <Feature: Outlet_Type>, <Feature: Item_MRP + Item_Visibility>, <Feature: Item_MRP + Item_Weight>, <Feature: Item_MRP + Outlet_Establishment_Year>, <Feature: Item_Visibility + Item_Weight>, <Feature: Item_Visibility + Outlet_Establishment_Year>, <Feature: Item_Weight + Outlet_Establishment_Year>, <Feature: Item_MRP * Item_Visibility>, <Feature: Item_MRP * Item_Weight>, <Feature: Item_MRP * Outlet_Establishment_Year>, <Feature: Item_Visibility * Item_Weight>, <Feature: Item_Visibility * Outlet_Establishment_Year>, <Feature: Item_Weight * Outlet_Establishment_Year>]
# Shape: (8523, 23)

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_dataframe_name = 'data', max_depth=2,
                                      trans_primitives = ['add_numeric', 'multiply_numeric'])

feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP + Outlet_Establishment_Year  Item_Visibility + Item_Weight  \
# index
# 0                                2248.8092                       9.316047
# 1                                2057.2692                       5.939278
# 2                                2140.6180                      17.516760
# 3                                2180.0950                      19.200000
# 4                                2040.8614                       8.930000
#
#        Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                      1999.016047
# 1                                      2009.019278
# 2                                      1999.016760
# 3                                      1998.000000
# 4                                      1987.000000
#
#        Item_Weight + Outlet_Establishment_Year  Item_MRP * Item_Visibility  \
# index
# 0                                      2008.30                    4.008763
# 1                                      2014.92                    0.930544
# 2                                      2016.50                    2.373528
# 3                                      2017.20                    0.000000
# 4                                      1995.93                    0.000000
#
#        Item_MRP * Item_Weight  Item_MRP * Outlet_Establishment_Year  \
# index
# 0                 2323.225560                           499368.5908
# 1                  285.753664                            96972.8228
# 2                 2478.315000                           283094.3820
# 3                 3496.224000                           363825.8100
# 4                  480.982302                           107022.6018
#
#        Item_Visibility * Item_Weight  \
# index
# 0                           0.149240
# 1                           0.114127
# 2                           0.293301
# 3                           0.000000
# 4                           0.000000
#
#        Item_Visibility * Outlet_Establishment_Year  \
# index
# 0                                        32.078555
# 1                                        38.729936
# 2                                        33.503390
# 3                                         0.000000
# 4                                         0.000000
#
#        Item_Weight * Outlet_Establishment_Year
# index
# 0                                     18590.70
# 1                                     11893.28
# 2                                     34982.50
# 3                                     38361.60
# 4                                     17743.91
#
# [5 rows x 23 columns]

# %%
# Check the feature definitions
print('Definitions:', feature_defs)
print('Shape:', feature_matrix.shape)
# Out:
# [<Feature: Item_Identifier>,
#  <Feature: Item_Weight>,
#  <Feature: Item_Fat_Content>,
#  <Feature: Item_Visibility>,
#  <Feature: Item_Type>,
#  <Feature: Item_MRP>,
#  <Feature: Outlet_Identifier>,
#  <Feature: Outlet_Establishment_Year>,
#  <Feature: Outlet_Size>,
#  <Feature: Outlet_Location_Type>,
#  <Feature: Outlet_Type>,
#  <Feature: Item_MRP + Item_Visibility>,
#  <Feature: Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility>,
#  <Feature: Item_Visibility * Item_Weight>,
#  <Feature: Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Weight>,
#  <Feature: Item_MRP * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_MRP + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Weight>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Weight>,
#  <Feature: Item_MRP + Item_Weight * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_Weight>,
#  <Feature: Item_MRP + Item_Visibility * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility>,
#  <Feature: Item_MRP + Item_Visibility * Item_MRP + Item_Weight>,
#  <Feature: Item_Visibility * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_MRP + Item_Visibility>,
#  <Feature: Item_MRP * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Weight>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Item_Weight>,
#  <Feature: Item_Weight + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility + Item_Weight>]
